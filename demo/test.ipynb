# %%
from core.data import (
    SplitConfig,
    prepare_cmapss_split,
)


config = SplitConfig(
    data_path="Data/train_FD001.txt",

    train_ratio=0.70,

    elbow_cycle=130,
    elbow_tolerance=20,

    extended_probability=0.30,
    extended_max_extra=50,

    min_cycles_before_failure=20,

    test_fraction_min=0.10,
    test_fraction_max=0.30,

    random_seed=42,
)


data = prepare_cmapss_split(config)

# %%
print(f"Total engines : {len(data['engine_data'])}")
print(f"Train engines : {len(data['train_ids'])}")
print(f"Test engines  : {len(data['test_ids'])}")

for engine_id in data["train_ids"][:5]:
    print(
        engine_id,
        "→",
        len(data["train_data"][engine_id]),
        "/",
        len(data["engine_data"][engine_id])
    )
# Out:
# Total engines : 100
# Train engines : 70
# Test engines  : 30
# 1 → 150 / 192
# 2 → 118 / 287
# 3 → 111 / 179
# 4 → 142 / 189
# 5 → 176 / 269

# %%
for engine_id in data["test_ids"][:30]:
    print(
        engine_id,
        "→",
        len(data["test_data"][engine_id]),
        "/",
        len(data["engine_data"][engine_id])
    )
# Out:
# 7 → 59 / 259
# 9 → 21 / 201
# 12 → 17 / 170
# 13 → 43 / 163
# 14 → 39 / 180
# 15 → 30 / 207
# 20 → 58 / 234
# 23 → 25 / 168
# 31 → 43 / 234
# 35 → 34 / 181
# 36 → 45 / 158
# 37 → 47 / 170
# 42 → 30 / 196
# 45 → 24 / 158
# 48 → 42 / 231
# 50 → 19 / 198
# 54 → 41 / 257
# 55 → 56 / 193
# 59 → 61 / 231
# 65 → 31 / 153
# 66 → 39 / 202
# 67 → 90 / 313
# 68 → 43 / 199
# 75 → 66 / 229
# 78 → 69 / 231
# 83 → 31 / 293
# 86 → 34 / 278
# 89 → 54 / 217
# 91 → 16 / 135
# 99 → 31 / 185

# %%
import sys
from pathlib import Path

from src.phaseI.main import run_phase1

model, stats, normalized_data = run_phase1(
    train_data=data["train_data"],
    n_sensors=len(data["sensors"]),
    window_len=30,
    latent_dim=16,
)
# Out:
# epoch   0 | recon_loss=0.605258
# epoch   1 | recon_loss=0.455235
# epoch   2 | recon_loss=0.451565
# epoch   3 | recon_loss=0.449019
# epoch   4 | recon_loss=0.447177
# epoch   5 | recon_loss=0.444726
# epoch   6 | recon_loss=0.442621
# epoch   7 | recon_loss=0.441373
# epoch   8 | recon_loss=0.440571
# epoch   9 | recon_loss=0.439688
# epoch  10 | recon_loss=0.438775
# epoch  11 | recon_loss=0.437534
# epoch  12 | recon_loss=0.436060
# epoch  13 | recon_loss=0.434140
# epoch  14 | recon_loss=0.430976
# epoch  15 | recon_loss=0.427377
# epoch  16 | recon_loss=0.423287
# epoch  17 | recon_loss=0.418792
# epoch  18 | recon_loss=0.416564
# epoch  19 | recon_loss=0.415569
# epoch  20 | recon_loss=0.415221
# epoch  21 | recon_loss=0.414672
# epoch  22 | recon_loss=0.414370
# epoch  23 | recon_loss=0.414349
# epoch  24 | recon_loss=0.414158
# epoch  25 | recon_loss=0.414116
# epoch  26 | recon_loss=0.413826
# epoch  27 | recon_loss=0.413793
# epoch  28 | recon_loss=0.413669
# epoch  29 | recon_loss=0.413556
